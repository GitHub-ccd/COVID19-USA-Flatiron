# %% [markdown]
# # COVID-19 dataset
#
# by http://ncov.bii.virginia.edu/dashboard/

# %%
# imports
import numpy as np
import pandas as pd

# %%
#load files


import os
from os.path import join, getsize
for root, dirs, files in os.walk('../Data/nssac-ncov-data-country-state'):
    #print(root, "consumes", end="")
    #print("\n")
    #print(sum([getsize(join(root, name)) for name in files]), end="")
    #print("bytes in", len(files), "non-directory files")
    #print([name for name in files if name.find('csv')])
    #print(type(files))
    #f_path='../Data/nssac-ncov-data-country-state/'+files[0]
    #day1 = pd.read_csv(f_path)
    #display(day1[day1.Region == 'USA'])
    
    for name in files:
        if name.endswith('.csv'):
            print(name)
            f_path='../Data/nssac-ncov-data-country-state/'+name
            day = pd.read_csv(f_path)
            display(day[day.Region == 'USA'])
# Out:
# nssac-ncov-sd-01-22-2020.csv
#           name Region          Last Update  Confirmed  Deaths  Recovered
# 27  Washington    USA  2020-01-22 12:00:00          1       0          0
# nssac-ncov-sd-01-23-2020.csv
#           name Region          Last Update  Confirmed  Deaths  Recovered
# 36  Washington    USA  2020-01-23 12:00:00          1       0          0
# nssac-ncov-sd-01-24-2020.csv
#           name Region          Last Update  Confirmed  Deaths  Recovered
# 36    Illinois    USA  2020-01-24 12:00:00          1       0          0
# 39  Washington    USA  2020-01-24 12:00:00          1       0          0
# nssac-ncov-sd-01-25-2020.csv
#           name Region          Last Update  Confirmed  Deaths  Recovered
# 40    Illinois    USA  2020-01-25 12:00:00          1       0          0
# 43  Washington    USA  2020-01-25 12:00:00          1       0          0
# nssac-ncov-sd-01-26-2020.csv
#           name Region          Last Update  Confirmed  Deaths  Recovered
# ...

# %%
# make df as needed for the bar chart race
